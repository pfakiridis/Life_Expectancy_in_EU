# %%
import pandas as pd
import matplotlib.pyplot  as plt

# %%
#Importing the csv file

life = pd.read_csv('life_expectancy.csv')

# %%
# Removing the Country Germany (until 1990 former territory of the FRG) as the country does not currently exist in this form.

life = life[life.Country != 'Germany (until 1990 former territory of the FRG)']

#Checking the data to make sure the name has been removed

life
# Out:
#            Country       Crime        Gdp  Median_Income    Life_Exp  \
# 0          Austria  124.200000   356237.6   30562.000000  811.700000
# 1          Belgium  157.800000   424660.3   24220.000000  807.800000
# 2         Bulgaria  262.600000    48128.6   48282.000000  743.200000
# 3          Croatia   32.000000    46639.5   54483.750000  772.900000
# 4           Cyprus  123.100000    18490.2   18965.000000  816.900000
# 5          Czechia  135.800000   176370.1   20181.000000  782.600000
# 6          Denmark  114.700000   282089.9   25955.000000  801.100000
# 7          Estonia  137.600000    21682.6   39275.000000  768.300000
# 8          Finland   88.400000   216073.0   22860.000000  808.700000
# 9           France  150.200000  2228568.0   24273.000000  822.200000
# 11          Greece  161.100000   176487.9   30718.000000  809.600000
# 12         Hungary  111.700000   113903.8   52333.000000  753.400000
# 13         Iceland   28.444444    18646.1   27636.666667  823.000000
# 14         Ireland  111.500000   273238.2   18424.000000  810.900000
# 15           Italy  152.800000  1689824.0   12797.000000  825.800000
# 16          Latvia  168.600000    25037.7   51832.000000  739.400000
# 17       Lithuania   54.100000    38849.4   52634.000000  739.800000
# 18      Luxembourg  125.300000    53303.0   39024.000000  816.300000
# 19           Malta  112.600000    10344.1   11829.000000  814.400000
# 20     Netherlands  176.100000   708337.0   26194.000000  813.200000
# 21          Norway   49.600000   335747.5   37533.000000  817.500000
# 22          Poland   62.700000   426547.5   45144.000000  769.800000
# 23        Portugal  109.100000   186480.5   36555.000000  807.000000
# 24         Romania  143.300000   170393.6   42222.000000  745.300000
# 25        Slovakia   89.400000    81226.1   40191.000000  763.100000
# 26        Slovenia   92.100000    40357.2    9318.000000  803.700000
# 27           Spain  120.100000  1118743.0   10535.000000  827.300000
# 28          Sweden  116.500000   463147.5   24885.000000  819.500000
# 29     Switzerland  131.777778   605753.7   36121.111111  829.500000
# 30          Turkey  106.375000   780224.9   45252.222222  776.222222
# 31  United Kingdom  201.000000  2403382.6   17457.000000  808.800000
#
#      Pollution     Savings  Unemployment  Work_hours  avg_temp  avg_high_temp  \
# 0   101.000000  236.800000          51.9       372.6      44.6           54.2
# 1   150.300000  249.500000          78.3       370.1      48.8           55.5
# 2   163.300000  589.200000          93.7       409.7      49.4           59.3
# 3    69.250000  620.750000         134.3       399.2      55.1           62.3
# 4   151.100000  516.000000         106.3       397.3      66.1           75.1
# 5   157.200000  375.200000          57.2       408.3      44.5           51.4
# 6    71.700000  256.800000          63.7       335.4      46.0           51.4
# 7   119.900000  367.900000          92.8       387.5      41.9           48.4
# 8    89.000000  283.800000          82.2       370.4      36.6           43.9
# 9   126.500000  327.200000          93.0       376.4      52.3           60.5
# 11  228.200000  414.900000         196.5       421.5      62.5           70.1
# 12  126.500000  671.400000          85.0       397.0      50.3           58.3
# 13   95.222222  326.111111          50.7       394.8      38.5           43.1
# 14   51.000000  496.200000         115.7       355.1      49.4           55.2
# 15  174.300000  377.000000         101.7       373.6      56.3           63.8
# 16  232.000000  677.700000         126.8       390.2      42.9           48.8
# 17  143.200000  546.000000         112.8       383.8      43.4           49.6
# 18  150.000000  230.100000          54.9       372.0      46.7           54.6
# 19  363.000000  248.000000          58.3       386.7      65.7           72.3
# 20  138.700000  217.200000          56.4       304.5      49.2           55.1
# 21   77.800000  138.300000          35.5       337.2      39.8           44.1
# 22  110.900000  470.700000          82.7       406.8      44.6           56.2
# 23  150.900000  347.500000         120.3       392.3      60.4           68.3
# 24  176.200000  497.100000          65.2       400.8      47.6           57.1
# 25  153.700000  372.200000         120.2       405.1      43.2           53.0
# 26  173.800000  435.900000          78.1       395.4      46.4           53.8
# 27  102.000000  384.800000         204.8       382.4      60.0           69.3
# 28   78.600000  203.100000          76.2       363.4      40.3           46.7
# 29   98.888889  201.888889          45.5       348.8      42.5           50.8
# 30  254.500000  510.000000         100.9       482.7      54.2           63.9
# 31  100.600000  363.400000          65.1       365.7      48.8           55.3
#
#     avg_low_temp  avg_precipitation
# 0           37.4               39.3
# 1           42.0               33.1
# 2           43.4               24.7
# 3           48.0               41.1
# 4           57.5               15.4
# 5           37.3               27.4
# 6           41.6               23.9
# 7           35.9               25.6
# 8           31.3               21.9
# 9           45.6               30.7
# 11          53.9               25.3
# 12          42.7               22.7
# 13          34.2               38.1
# 14          44.0               40.8
# 15          49.1               30.4
# 16          38.2               23.2
# 17          36.9               26.3
# 18          41.2               32.4
# 19          59.1               22.0
# 20          43.7               29.7
# 21          33.8               44.2
# 22          33.8               24.6
# 23          54.2               32.5
# 24          41.1               24.7
# 25          36.0               26.2
# 26          38.7               49.1
# 27          52.3               21.7
# 28          33.6               22.6
# 29          35.8               46.7
# 30          44.6               25.7
# 31          42.9               29.7

# %%
#Summary statistics for the dataset

life.describe()
# Out:
#             Crime           Gdp  Median_Income    Life_Exp   Pollution  \
# count   31.000000  3.100000e+01      31.000000   31.000000   31.000000
# mean   120.987007  4.367392e+05   31538.443548  795.126523  141.266487
# std     48.559145  6.215477e+05   13528.667315   29.085654   63.720144
# min     28.444444  1.034410e+04    9318.000000  739.400000   51.000000
# 25%     99.237500  4.738405e+04   21520.500000  771.350000   99.744444
# 50%    120.100000  1.864805e+05   30562.000000  808.700000  138.700000
# 75%    146.750000  4.448475e+05   41206.500000  816.600000  160.250000
# max    262.600000  2.403383e+06   54483.750000  829.500000  363.000000
#
#           Savings  Unemployment  Work_hours   avg_temp  avg_high_temp  \
# count   31.000000     31.000000   31.000000  31.000000      31.000000
# mean   385.569355     90.538710  383.441935  48.967742      56.496774
# std    145.387774     39.291438   31.152076   7.823528       8.431152
# min    138.300000     35.500000  304.500000  36.600000      43.100000
# 25%    253.150000     61.000000  370.250000  43.300000      51.100000
# 50%    372.200000     82.700000  386.700000  47.600000      55.200000
# 75%    496.650000    109.550000  398.250000  53.250000      61.400000
# max    677.700000    204.800000  482.700000  66.100000      75.100000
#
#        avg_low_temp  avg_precipitation
# count     31.000000          31.000000
# mean      42.251613          29.732258
# std        7.375042           8.247924
# min       31.300000          15.400000
# 25%       36.450000          24.250000
# 50%       41.600000          26.300000
# 75%       45.100000          32.800000
# max       59.100000          49.100000

# %%
# The variables Life_Exp and Work_Hours have been imputing with incorrect decimal so we divide these values by 10 to fix this!

life['Life_Exp'] = life['Life_Exp'] / 10
life['Work_hours'] = life['Work_hours'] / 10

# %%
#Filtering the five countries with the highest life expectancy
life_large.sort_values('Life_Exp', ascending=False, inplace=True)

life.nlargest(5,'Life_Exp')
life_large = life.nlargest(5,'Life_Exp')
life_large
# Out:
#         Country       Crime        Gdp  Median_Income  Life_Exp   Pollution  \
# 29  Switzerland  131.777778   605753.7   36121.111111     82.95   98.888889
# 27        Spain  120.100000  1118743.0   10535.000000     82.73  102.000000
# 15        Italy  152.800000  1689824.0   12797.000000     82.58  174.300000
# 13      Iceland   28.444444    18646.1   27636.666667     82.30   95.222222
# 9        France  150.200000  2228568.0   24273.000000     82.22  126.500000
#
#        Savings  Unemployment  Work_hours  avg_temp  avg_high_temp  \
# 29  201.888889          45.5       34.88      42.5           50.8
# 27  384.800000         204.8       38.24      60.0           69.3
# 15  377.000000         101.7       37.36      56.3           63.8
# 13  326.111111          50.7       39.48      38.5           43.1
# 9   327.200000          93.0       37.64      52.3           60.5
#
#     avg_low_temp  avg_precipitation
# 29          35.8               46.7
# 27          52.3               21.7
# 15          49.1               30.4
# 13          34.2               38.1
# 9           45.6               30.7

# %%
#Filtering the five countries with the lowest life expectancy
life_small.sort_values('Life_Exp', ascending=False, inplace=True)

life.nsmallest(5,'Life_Exp')
life_small = life.nsmallest(5,'Life_Exp')
life_small
# Out:
#       Country  Crime       Gdp  Median_Income  Life_Exp  Pollution  Savings  \
# 16     Latvia  168.6   25037.7        51832.0     73.94      232.0    677.7
# 17  Lithuania   54.1   38849.4        52634.0     73.98      143.2    546.0
# 2    Bulgaria  262.6   48128.6        48282.0     74.32      163.3    589.2
# 24    Romania  143.3  170393.6        42222.0     74.53      176.2    497.1
# 12    Hungary  111.7  113903.8        52333.0     75.34      126.5    671.4
#
#     Unemployment  Work_hours  avg_temp  avg_high_temp  avg_low_temp  \
# 16         126.8       39.02      42.9           48.8          38.2
# 17         112.8       38.38      43.4           49.6          36.9
# 2           93.7       40.97      49.4           59.3          43.4
# 24          65.2       40.08      47.6           57.1          41.1
# 12          85.0       39.70      50.3           58.3          42.7
#
#     avg_precipitation
# 16               23.2
# 17               26.3
# 2                24.7
# 24               24.7
# 12               22.7

# %%
#Boxplot of the Life Expectancy in Europe. We see also from the boxplot that the median value 
#is around 81 despite that the mean is much loweer to 79.5.

plt.figure(figsize = (4,6))
labels= ['Life Expectancy']
plt.boxplot(life.Life_Exp, labels=labels)

plt.style.use('ggplot')
plt.title('Boxplot of Life Expectancy in Europe')

plt.show()

# %%
#The histogram of the life expectancy, the dashed black line represents the mean value/

plt.style.use('default')

# Since there were some gaps between the default histogram, the below bins have been created to present it in a more elegant way.
bins = [74,75,76,77,78,80,81,82,83]
mean = 79.5
plt.hist(life.Life_Exp, color='b', bins=bins)
plt.axvline(mean, color='k', linestyle='dashed', linewidth=2, label='mean')
plt.title('Histogram of Life Expectancy')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

plt.show()

# %%
#Plotting the countries with the lowest and highest life expectancy in Europe.
#It is observed that countries from the Eastern part of Europe show lower life expectancy.

plt.style.use('ggplot')
plt.xlim((72,85))
mean = 79.5
plt.scatter(life_small.Life_Exp, life_small.Country,s=60)
plt.scatter(life_large.Life_Exp, life_large.Country,s=60)
plt.axvline(mean, color='k', linestyle='dashed', linewidth=2, label='mean')
plt.title('Highest and Lowest Life Expectancy in Europe')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

# %%
#The histrograms of Crime and Working Hours observe a normal distribution. 
#The histrogram of working hours shows that there is/are some countries where the average working hours are around50.

plt.style.use('ggplot')

fig, axs = plt.subplots(1,2)

bins_crime = [40,80,120,160,200,240,280]
crime = life['Crime'].hist(ax=axs[0], bins=bins_crime)
crime.set_title("Histogram of Crime")
crime.legend()

plt.xticks(bins_crime)

bins_work = [30,32,34,36,38,40,42,44,50]
work = life['Work_hours'].hist(ax=axs[1],bins=bins_work)
work.set_title("Histogram of Working Hours")
work.legend()
plt.xticks(bins_work)

plt.show()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
# Filtering the five countries with the higher rate of working hours. 
#Taking into consideration that Turkey does not belong in the European Union, Greece is the country wth the highest rate.

life.nlargest(5,'Work_hours')
life_work = life.nlargest(5,'Work_hours')
life_work
# Out:
#      Country    Crime       Gdp  Median_Income   Life_Exp  Pollution  Savings  \
# 30    Turkey  106.375  780224.9   45252.222222  77.622222      254.5    510.0
# 11    Greece  161.100  176487.9   30718.000000  80.960000      228.2    414.9
# 2   Bulgaria  262.600   48128.6   48282.000000  74.320000      163.3    589.2
# 5    Czechia  135.800  176370.1   20181.000000  78.260000      157.2    375.2
# 22    Poland   62.700  426547.5   45144.000000  76.980000      110.9    470.7
#
#     Unemployment  Work_hours  avg_temp  avg_high_temp  avg_low_temp  \
# 30         100.9       48.27      54.2           63.9          44.6
# 11         196.5       42.15      62.5           70.1          53.9
# 2           93.7       40.97      49.4           59.3          43.4
# 5           57.2       40.83      44.5           51.4          37.3
# 22          82.7       40.68      44.6           56.2          33.8
#
#     avg_precipitation
# 30               25.7
# 11               25.3
# 2                24.7
# 5                27.4
# 22               24.6

# %%
# Filtering the five countries with the lower rate of working hours. 

life.nsmallest(5,'Work_hours')
life_work_small = life.nsmallest(5,'Work_hours')
life_work_small
# Out:
#         Country       Crime       Gdp  Median_Income  Life_Exp   Pollution  \
# 20  Netherlands  176.100000  708337.0   26194.000000     81.32  138.700000
# 6       Denmark  114.700000  282089.9   25955.000000     80.11   71.700000
# 21       Norway   49.600000  335747.5   37533.000000     81.75   77.800000
# 29  Switzerland  131.777778  605753.7   36121.111111     82.95   98.888889
# 14      Ireland  111.500000  273238.2   18424.000000     81.09   51.000000
#
#        Savings  Unemployment  Work_hours  avg_temp  avg_high_temp  \
# 20  217.200000          56.4       30.45      49.2           55.1
# 6   256.800000          63.7       33.54      46.0           51.4
# 21  138.300000          35.5       33.72      39.8           44.1
# 29  201.888889          45.5       34.88      42.5           50.8
# 14  496.200000         115.7       35.51      49.4           55.2
#
#     avg_low_temp  avg_precipitation
# 20          43.7               29.7
# 6           41.6               23.9
# 21          33.8               44.2
# 29          35.8               46.7
# 14          44.0               40.8

# %%
#Presenting a scatterplot with the five countries with the lowest and highest working hours in Europe

plt.style.use('ggplot')
mean = 38.3
plt.scatter(life_work.Work_hours, life_work.Country)
plt.scatter(life_work_small.Work_hours, life_work_small.Country)
plt.axvline(mean,color='k', linestyle='dashed', linewidth=2, label='mean')
plt.title('Working Hours in Europe(per week)')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

# %%
#Comparing the rates of pollution in comparison to Life expectancy.

plt.style.use('ggplot')
mean = 144
plt.scatter(life.Pollution, life.Life_Exp)
plt.axvline(mean, color='b', linestyle='dashed', linewidth=1.5, label='mean')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.title('Pollution Compared to Life Expectancy')
plt.ylabel('Life Expectancy')
plt.xlabel('Pollution Rate')
# Out:
# Text(0.5, 0, 'Pollution Rate')

# %%
#Comparing the working hours in comparison to Life expectancy.


plt.style.use('ggplot')

mean = 38.2

plt.scatter(life.Work_hours, life.Life_Exp)
plt.axvline(mean, color='b', linestyle='dashed', linewidth=1.5, label='mean')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.title('Working Hours Compared to Life Expectancy')
plt.ylabel('Work Hours')
plt.xlabel('Life Expectancy')
# Out:
# Text(0.5, 0, 'Life Expectancy')

# %%
# The general picture of the life expectancy in Europe.

plt.style.use('ggplot')
fig.set_size_inches(10, 5)
plt.figure(figsize=(10,12))

life.sort_values('Life_Exp', ascending=True, inplace=True)

plt.scatter(life.Life_Exp, life.Country)
plt.xlabel('Life Expectancy')
plt.title('Life Expectancy in Europe')
# Out:
# Text(0.5, 1.0, 'Life Expectancy in Europe')

# %%
#Presenting a second scatterplot with the five countries with the lowest and highest working hours in Europe

fig, axs = plt.subplots(2)

fig.suptitle('Higher and Lower Working Hours (per week)')

df = axs[0].scatter(life_work.Work_hours, life_work.Country)
nf = axs[1].scatter(life_work_small.Work_hours, life_work_small.Country)

# %%
#Boxplot with other variables in the dataset
boxplot = life.boxplot(column=[ 'Unemployment', 'Crime', 'Savings', 'Pollution'])
